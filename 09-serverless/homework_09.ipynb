# %%
DATA_URL="https://github.com/alexeygrigorev/large-datasets/releases/download/hairstyle/hair_classifier_v1.onnx.data"
MODEL_URL="https://github.com/alexeygrigorev/large-datasets/releases/download/hairstyle/hair_classifier_v1.onnx"
# !wget $DATA_URL
# !wget $MODEL_URL
# Out:
# --2025-12-11 16:23:08--  https://github.com/alexeygrigorev/large-datasets/releases/download/hairstyle/hair_classifier_v1.onnx.data
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !pip install onnxruntime torch==2.8.0 torchvision pillow
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: C:\Users\gopu\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
import onnxruntime as ort

onnx_model_path = "hair_classifier_v1.onnx"
session = ort.InferenceSession(onnx_model_path, providers=["CPUExecutionProvider"])
inputs = session.get_inputs()
outputs = session.get_outputs()

input_name = inputs[0].name
output_name = outputs[0].name
output_name
# Out:
# 'output'

# %%
# !wget "https://habrastorage.org/webt/yf/_d/ok/yf_dokzqy3vcritme8ggnzqlvwa.jpeg"
# Out:
# --2025-12-11 16:23:44--  https://habrastorage.org/webt/yf/_d/ok/yf_dokzqy3vcritme8ggnzqlvwa.jpeg
# Resolving habrastorage.org (habrastorage.org)... 95.47.173.34, 95.47.173.35
# Connecting to habrastorage.org (habrastorage.org)|95.47.173.34|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 398272 (389K) [image/jpeg]
# Saving to: 'yf_dokzqy3vcritme8ggnzqlvwa.jpeg'
#
#      0K .......... .......... .......... .......... .......... 12% 1,04M 0s
#     50K .......... .......... .......... .......... .......... 25% 1,05M 0s
#    100K .......... .......... .......... .......... .......... 38% 7,43M 0s
#    150K .......... .......... .......... .......... .......... 51% 1,63M 0s
#    200K .......... .......... .......... .......... .......... 64% 2,63M 0s
#    250K .......... .......... .......... .......... .......... 77% 6,80M 0s
#    300K .......... .......... .......... .......... .......... 89% 7,84M 0s
# ...

# %%
from io import BytesIO
from urllib import request

from PIL import Image
import numpy as np
from torchvision import transforms

def download_image(url):
    with request.urlopen(url) as resp:
        buffer = resp.read()
    stream = BytesIO(buffer)
    img = Image.open(stream)
    return img

def prepare_image(img, target_size):
    if img.mode != 'RGB':
        img = img.convert('RGB')
    img = img.resize(target_size, Image.NEAREST)
    return img

target_size=(200,200)
image_url='https://habrastorage.org/webt/yf/_d/ok/yf_dokzqy3vcritme8ggnzqlvwa.jpeg'
img = download_image('https://habrastorage.org/webt/yf/_d/ok/yf_dokzqy3vcritme8ggnzqlvwa.jpeg')

resized_img = prepare_image(img, target_size)
preprocess = transforms.Compose([
    transforms.Resize((200,200)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])
input_tensor = preprocess(resized_img)
input_tensor[0, 0, 0].item()
# Out:
# -1.0732940435409546

# %%
preds = session.run(
        output_names=[output_name],
        input_feed={input_name: input_tensor.unsqueeze(0).numpy() }
    )
preds[0][0].tolist()[0]
# Out:
# 0.09156641364097595

# %%
MODEL_URL="https://github.com/alexeygrigorev/large-datasets/releases/download/hairstyle/hair_classifier_empty.onnx"
# !wget $MODEL_URL
# Out:
# --2025-12-11 16:24:15--  https://github.com/alexeygrigorev/large-datasets/releases/download/hairstyle/hair_classifier_empty.onnx
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
from io import BytesIO
from urllib import request

from PIL import Image
import numpy as np
from torchvision import transforms

import onnxruntime as ort

onnx_model_path = 'hair_classifier_v1.onnx'
session = ort.InferenceSession(onnx_model_path, providers=["CPUExecutionProvider"])
input_name = session.get_inputs()[0].name
output_name = session.get_outputs()[0].name
target_size = (200,200)
def download_image(url):
    with request.urlopen(url) as resp:
        buffer = resp.read()
    stream = BytesIO(buffer)
    img = Image.open(stream)
    return img

def prepare_image(img, target_size):
    if img.mode != 'RGB':
        img = img.convert('RGB')
    img = img.resize(target_size, Image.NEAREST)
    return img

preprocessor = transforms.Compose([
    transforms.Resize(target_size),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

def preprocess(img):
  resized_img = prepare_image(img, target_size)
  input_tensor = preprocessor(resized_img)
  X = input_tensor.unsqueeze(0).numpy()
  return X


def predict(url):
    img = download_image(url)
    X = preprocess(img)

    preds = session.run(
        output_names=[output_name],
        input_feed={input_name:X }
    )

    # What happens here is we take an Numpy array and
    # it will be converted to usual python list with usual python floats.
    float_predictions = preds[0][0].tolist()[0]

    return float_predictions

def lambda_handler(event, context):
    url = event['url']
    result = predict(url)
    return result

predict('https://habrastorage.org/webt/yf/_d/ok/yf_dokzqy3vcritme8ggnzqlvwa.jpeg')
# Out:
# 0.09156641364097595

# %%
# !docker pull agrigorev/model-2025-hairstyle:v1
# Out:
# v1: Pulling from agrigorev/model-2025-hairstyle
# Digest: sha256:9e43d5a5323f7f07688c0765d3c0137af66d0154af37833ed721d6b4de6df528
# Status: Image is up to date for agrigorev/model-2025-hairstyle:v1
# docker.io/agrigorev/model-2025-hairstyle:v1

# %%
# !docker images

# %%
# !docker build -t hair_style_classifier:v1 .
# Out:
# ^C

# %%
import requests
import json

invoke_url = "http://localhost:9000/2015-03-31/functions/function/invocations"
payload = {"url": "https://habrastorage.org/webt/yf/_d/ok/yf_dokzqy3vcritme8ggnzqlvwa.jpeg"}

# Make the POST request
response = requests.post(invoke_url, headers={"Content-Type": "application/json"}, data=json.dumps(payload))

print(response.json())
# Out:
# {'statusCode': 200, 'body': '{"prediction": -0.08359654247760773}'}
